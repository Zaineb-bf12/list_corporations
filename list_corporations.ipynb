# %%
import pandas as pd
data = pd.read_csv('C:/Users/zaineb/Desktop/data/list_corporations.csv')
data.shape
data.columns
data
# Out:
#       rank                                            profile  \
# 0        1               https://www.inc.com/profile/freestar
# 1        2            https://www.inc.com/profile/freightwise
# 2        3           https://www.inc.com/profile/ceces-veggie
# 3        4               https://www.inc.com/profile/ladyboss
# 4        5                 https://www.inc.com/profile/perpay
# ...    ...                                                ...
# 5007  4996   https://www.inc.com/profile/village-plumbing-air
# 5008  4997  https://www.inc.com/profile/real-restoration-g...
# 5009  4998          https://www.inc.com/profile/naval-systems
# 5010  4999            https://www.inc.com/profile/hnm-systems
# 5011  5000                https://www.inc.com/profile/vivayic
#
#                         name                        url state       revenue  \
# 0                   Freestar        http://freestar.com    AZ  36.9 Million
# 1                FreightWise  http://freightwisellc.com    TN  33.6 Million
# 2          Cece's Veggie Co.   http://cecesveggieco.com    TX  24.9 Million
# 3                   LadyBoss        http://ladyboss.com    NM  32.4 Million
# 4                     Perpay          http://perpay.com    PA  22.5 Million
# ...                      ...                        ...   ...           ...
# 5007  Village Plumbing & Air        villageplumbing.com    TX  15.8 Million
# 5008  Real Restoration Group        realrestoration.com    IL  11.6 Million
# 5009           Naval Systems                   n-s-i.us    MD  29.7 Million
# 5010             HNM Systems             hnmsystems.com    CA   8.8 Million
# 5011                 Vivayic                vivayic.com    NE   4.5 Million
#
#         growth_%                      industry  workers  previous_workers  \
# 0     36680.3882       Advertising & Marketing     40.0                 5
# 1     30547.9317    Logistics & Transportation     39.0                 8
# 2     23880.4852               Food & Beverage    190.0                10
# 3     21849.8925  Consumer Products & Services     57.0                 2
# 4     18166.4070                        Retail     25.0                 6
# ...          ...                           ...      ...               ...
# 5007     52.2377  Consumer Products & Services     88.0                62
# 5008     52.2127                  Construction    380.0               220
# 5009     52.2037           Government Services    187.0               127
# 5010     52.1919            Telecommunications    132.0                47
# 5011     52.1691  Business Products & Services     27.0                22
#
#       founded  yrs_on_list         metro            city
# 0        2015            1       Phoenix         Phoenix
# 1        2015            1     Nashville       Brentwood
# 2        2015            1        Austin          Austin
# 3        2014            1           NaN     Albuquerque
# 4        2014            1  Philadelphia    Philadelphia
# ...       ...          ...           ...             ...
# 5007     1946            3       Houston         Houston
# 5008     2011            1       Chicago         Chicago
# 5009     2004            1           NaN  LEXINGTON PARK
# 5010     2011            1     San Diego    Solana Beach
# 5011     2006            4           NaN         Lincoln
#
# [5012 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
import matplotlib.pyplot as plt
#1- List average revenue of companies grouped by industry
data_sample = data[['name','revenue','industry']]
data_sample['revenue'] = data_sample['revenue'].str.replace("Million", "")
data_sample['revenue'] = data_sample['revenue'].str.replace("Billion", "")
data_sample['revenue']=  data_sample['revenue'].astype(float)
sum = data_sample.groupby(by=['industry']).sum()
industry = data_sample['industry'].unique()

fig1 = plt.figure()
ax = fig1.add_axes([1,100,7,1])
revenue = sum['revenue']
plt.bar(industry,revenue,
        width = 0.4)
 
plt.xlabel("industry")
plt.ylabel("revenue")
plt.title(" List average revenue of companies grouped by industry")

plt.show()
# Out:
# C:\Users\zaineb\AppData\Local\Temp/ipykernel_87880/1306796074.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sample['revenue'] = data_sample['revenue'].str.replace("Million", "")
# C:\Users\zaineb\AppData\Local\Temp/ipykernel_87880/1306796074.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sample['revenue'] = data_sample['revenue'].str.replace("Billion", "")
# C:\Users\zaineb\AppData\Local\Temp/ipykernel_87880/1306796074.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sample['revenue']=  data_sample['revenue'].astype(float)

# %%
#2- List top 5 industries repsented in the list
sum_tri = sum.sort_values(by=['revenue'])
s = sum_tri[-5:]
fig2 = plt.figure()
ax = fig2.add_axes([1,1,2,1])
revenue_tri = s["revenue"]
industry_tri = s.index
plt.bar(industry_tri,revenue_tri, color ='green',
        width = 0.4)
 
plt.xlabel("industry")
plt.ylabel("revenue")
plt.title(" mean revenue among industries")

plt.show()

# %%
#3- Show mean revenue among industries
data_sample = data[['name','revenue','industry']]
data_sample["revenue"] = data_sample["revenue"].str.replace("Million", "")
data_sample["revenue"] = data_sample["revenue"].str.replace("Billion", "")
data_sample["revenue"]=  data_sample["revenue"].astype(float)
mean = data_sample.groupby(by=["industry"]).mean()
industry = data_sample["industry"].unique()

fig3 = plt.figure()
ax = fig3.add_axes([1,100,7,1])
revenue = mean["revenue"]

plt.bar(industry, revenue, color ='maroon',
        width = 0.4)
 
plt.xlabel("industry")
plt.ylabel("revenue")
plt.title(" mean revenue among industries")
plt.show()
# Out:
# C:\Users\zaineb\AppData\Local\Temp/ipykernel_87880/611183485.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sample["revenue"] = data_sample["revenue"].str.replace("Million", "")
# C:\Users\zaineb\AppData\Local\Temp/ipykernel_87880/611183485.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sample["revenue"] = data_sample["revenue"].str.replace("Billion", "")
# C:\Users\zaineb\AppData\Local\Temp/ipykernel_87880/611183485.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_sample["revenue"]=  data_sample["revenue"].astype(float)

# %%
#4- Top 10 industries that has the largest growth rate
data_sample = data[['industry','revenue','growth_%']]

sum_tri = data_sample.sort_values(by=['growth_%'])
print(sum_tri)
s = sum_tri.tail(10)
fig4 = plt.figure()
ax = fig4.add_axes([1,12,3,1])
revenue_tri = s["growth_%"]
industry_tri = s["industry"]
plt.bar(industry_tri,revenue_tri, color ='maroon',
        width = 0.4)
plt.xlabel("industry")
plt.ylabel("revenue")
plt.title(" Top 10 industries that has the largest growth rate")
plt.show()
# Out:
#                           industry       revenue    growth_%
# 5011  Business Products & Services   4.5 Million     52.1691
# 5010            Telecommunications   8.8 Million     52.1919
# 5009           Government Services  29.7 Million     52.2037
# 5008                  Construction  11.6 Million     52.2127
# 5007  Consumer Products & Services  15.8 Million     52.2377
# ...                            ...           ...         ...
# 4                           Retail  22.5 Million  18166.4070
# 3     Consumer Products & Services  32.4 Million  21849.8925
# 2                  Food & Beverage  24.9 Million  23880.4852
# 1       Logistics & Transportation  33.6 Million  30547.9317
# 0          Advertising & Marketing  36.9 Million  36680.3882
#
# [5012 rows x 3 columns]

# %%
#5- List companies that have the largest increase in staff/new hires
data = pd.read_csv('C:/Users/zaineb/Desktop/data/list_corporations.csv')

data_sample = data[['name','workers','previous_workers']]

data_sample = data_sample.assign(Soustraire = data_sample['workers'] - data_sample['previous_workers'])
data_sample = data_sample.sort_values(by=['Soustraire'])
Soustraire = data_sample.tail(10)
fig5 = plt.figure()
ax = fig5.add_axes([1,12,3,1])
Soustr= Soustraire["Soustraire"]
name = Soustraire["name"]
ax.bar(name,Soustr)
plt.show()

# %%
#6- List companies that increased revenue while reducing staff

data_sample = data[['name','workers','previous_workers', 'growth_%']]

data_sample = data_sample.assign(Soustraire = data_sample['workers'] - data_sample['previous_workers'])
data_sample = data_sample.sort_values(by=['growth_%','Soustraire'])
print(data_sample)
Soustraire = data_sample.tail(10)

fig6 = plt.figure()
ax = fig6.add_axes([1,12,3,1])
Soustr= Soustraire["growth_%"]
name = Soustraire["name"]
ax.bar(name,Soustr)
plt.show()
# Out:
#                         name  workers  previous_workers    growth_%  \
# 5011                 Vivayic     27.0                22     52.1691
# 5010             HNM Systems    132.0                47     52.1919
# 5009           Naval Systems    187.0               127     52.2037
# 5008  Real Restoration Group    380.0               220     52.2127
# 5007  Village Plumbing & Air     88.0                62     52.2377
# ...                      ...      ...               ...         ...
# 4                     Perpay     25.0                 6  18166.4070
# 3                   LadyBoss     57.0                 2  21849.8925
# 2          Cece's Veggie Co.    190.0                10  23880.4852
# 1                FreightWise     39.0                 8  30547.9317
# 0                   Freestar     40.0                 5  36680.3882
#
#       Soustraire
# 5011         5.0
# 5010        85.0
# 5009        60.0
# 5008       160.0
# 5007        26.0
# ...          ...
# 4           19.0
# 3           55.0
# 2          180.0
# 1           31.0
# 0           35.0
#
# [5012 rows x 5 columns]
